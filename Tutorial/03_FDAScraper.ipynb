# %% [markdown]
# # Scrape Information from the FDA
#
# The openFDA contains information to obtain data from their JSON file (see tutorial [here](01_Fetch_Data.ipynb)). However, the information is updated regularly. During testing, it was seen that the information in that data extended up to 2020. As a workaround, drug_nme includes additional methods to extract information from the FDA from several sources, which will be demoed below.

# %% [markdown]
# ### Initialize the FDAScrapper() class
#
# The FDASCrapper() class will need to be initialized. This class can take several parameters.
# - url: the url to a specific site. By default, it will point to the [NME Drug and New Biologic Approvals](https://www.fda.gov/drugs/nda-and-bla-approvals/new-molecular-entity-nme-drug-and-new-biologic-approvals) page.
# - compilation_link: A link to the page containing the [Compilation of CDER NME Drug and New Biologic Approvals](https://www.fda.gov/drugs/drug-approvals-and-databases/compilation-cder-new-molecular-entity-nme-drug-and-new-biologic-approvals).
# - latest_link: A link to the page containing the [Novel Drug Approvals at FDA](https://www.fda.gov/drugs/development-approval-process-drugs/novel-drug-approvals-fda).
#
# By default, these are already set to the specific web addresses. However, if there are issues, users can try to use different sites. They can be set to the paramaters manually.

# %%
import pandas as pd
from tqdm import tqdm
from drug_nme import FDAScraper
scrape = FDAScraper()

# %% [markdown]
# ### Get NMEs From PDF Reports
#
# The FDA curates reports of approval by [calendar year](https://www.fda.gov/drugs/nda-and-bla-approvals/new-molecular-entity-nme-drug-and-new-biologic-approvals). The **get.pdf_links()** method will extract links to the PDFs.
#
# This will result in a dictionary containing the year and a link to the corresponding PDF report. This can be viewed by clicking or copy and pasting the link to the browser.  The links are also used to set the instance variable. Thus, it is not necessary to set the **get_pdf_links()** to a variable.
#
# **NOTE:** Currently, the FDA curates reports from 2015-2023. There are additional reports available for 1999-2014, however it is listed under the FDA Archive link. Extraction there can be difficult. A workaround will be demoed further below.

# %%
# set to variable to demo the output
links = scrape.get_pdf_links()
links
# Out:
# {'2023': 'https://www.fda.gov/media/177083/download?attachment',
#  '2022': 'https://www.fda.gov/media/165828/download?attachment',
#  '2021': 'https://www.fda.gov/media/158152/download?attachment',
#  '2020': 'https://www.fda.gov/media/147400/download?attachment',
#  '2019': 'https://www.fda.gov/media/147414/download?attachment',
#  '2018': 'https://www.fda.gov/media/124809/download?attachment',
#  '2017': 'https://www.fda.gov/media/110746/download',
#  '2016': 'https://www.fda.gov/media/102967/download',
#  '2015': 'https://www.fda.gov/media/93424/download'}

# %% [markdown]
# ### Extract Table From PDF Report
#
# The above **get_pdf_links** method sets the instance variable in the FDAScrapper class. This can the nbe used to extract the table from the PDF file using the **extract_table()**.

# %%
year_2023 = scrape.extract_table(year='2023')
year_2023.head()
# Out:
# 0 APPLICATION NUMBER PROPRIETARY NAME ESTABLISHED NAME  \
# 1         NDA 214373        BRENZAVVY    BEXAGLIFLOZIN
# 2         NDA 216059         JAYPIRCA    PIRTOBRUTINIB
# 3         NDA 217639          ORSERDU      ELACESTRANT
# 4         NDA 216951        JESDUVROQ      DAPRODUSTAT
# 5         NDA 216403         FILSPARI       SPARSENTAN
#
# 0                                          APPLICANT REVIEW CLASSIFICATION  \
# 1                                    THERACOSBIO LLC                     S
# 2                                  LOXO ONCOLOGY INC                   P,O
# 3                          STEMLINE THERAPEUTICS INC                     P
# 4  GLAXOSMITHKLINE INTELLECTUAL PROPERTY NO 2 LTD...                     S
# 5                           TRAVERE THERAPEUTICS INC                   P,O
#
# 0 APPROVAL DATE                                         INDICATION
# 1     1/20/2023  ADJUNCT TO DIET AND EXERCISE TO IMPROVE GLYCEM...
# 2     1/27/2023  FOR THE TREATMENT OF ADULT PATIENTS WITH RELAP...
# 3     1/27/2023  FOR THE TREATMENT OF POSTMENOPAUSAL WOMEN OR A...
# 4      2/1/2023  FOR THE TREATMENT OF ANEMIA DUE TO CHRONIC KID...
# 5     2/17/2023  TO REDUCE PROTEINURIA IN ADULTS WITH PRIMARY I...

# %% [markdown]
# ### Extract Table From Multiple Years
# The above example is great for a single year. Multiple years can be obtained using a loop. The link dictionary demoed above will be looped and the table for each key/item pair will be extracted. Then the tables will be combined to generate a single pd.DataFrame for NME across the indicated years.

# %%
# Empty list to hold pd.DataFrame
tables = []

# Extract table for all years in dictionary
for year, table in tqdm(links.items(), desc='Extracting tables'):
    data = scrape.extract_table(year=year)
    tables.append(data)
    
# Combine tables into a single pd.DataFrame
tables = pd.concat(tables, ignore_index=True)
tables
# Out:
# Extracting tables: 100%|██████████| 9/9 [00:01<00:00,  5.42it/s]
#     APPLICATION NUMBER PROPRIETARY NAME ESTABLISHED NAME  \
# 0           NDA 214373        BRENZAVVY    BEXAGLIFLOZIN
# 1           NDA 216059         JAYPIRCA    PIRTOBRUTINIB
# 2           NDA 217639          ORSERDU      ELACESTRANT
# 3           NDA 216951        JESDUVROQ      DAPRODUSTAT
# 4           NDA 216403         FILSPARI       SPARSENTAN
# ..                 ...              ...              ...
# 300     BLA 125526/0.0           NUCALA      MEPOLIZUMAB
# 301     BLA 761036/0.0         DARZALEX      DARATUMUMAB
# 302     BLA 125547/0.0        PORTRAZZA      NECITUMUMAB
# 303     BLA 761035/0.0        EMPLICITI       ELOTUZUMAB
# 304     BLA 125561/0.0           KANUMA  SEBELIPASE ALFA
#
#                                              APPLICANT REVIEW CLASSIFICATION  \
# 0                                      THERACOSBIO LLC                     S
# 1                                    LOXO ONCOLOGY INC                   P,O
# 2                            STEMLINE THERAPEUTICS INC                     P
# 3    GLAXOSMITHKLINE INTELLECTUAL PROPERTY NO 2 LTD...                     S
# 4                             TRAVERE THERAPEUTICS INC                   P,O
# ..                                                 ...                   ...
# 300                                GLAXOSMITHKLINE LLC                     S
# 301                              JANSSEN BIOTECH, INC.                   P,O
# 302                              ELI LILLY AND COMPANY                     S
# 303                       BRISTOL-MYERS SQUIBB COMPANY                   P,O
# 304                            SYNAGEVA BIOPHARMA CORP                   P,O
#
#     APPROVAL DATE                                         INDICATION  \
# 0       1/20/2023  ADJUNCT TO DIET AND EXERCISE TO IMPROVE GLYCEM...
# 1       1/27/2023  FOR THE TREATMENT OF ADULT PATIENTS WITH RELAP...
# 2       1/27/2023  FOR THE TREATMENT OF POSTMENOPAUSAL WOMEN OR A...
# 3        2/1/2023  FOR THE TREATMENT OF ANEMIA DUE TO CHRONIC KID...
# 4       2/17/2023  TO REDUCE PROTEINURIA IN ADULTS WITH PRIMARY I...
# ..            ...                                                ...
# 300     11/4/2015  INDICATED FOR THE ADD-ON MAINTENANCE TREATMENT...
# 301    11/16/2015  INDICATED FOR TREATMENT OF PATIENTS WITH MULTI...
# 302    11/24/2015  IS INDICATED, IN COMBINATION WITH GEMCITABINE ...
# 303    11/30/2015  INDICATED IN COMBINATION WITH LENALIDOMIDE AND...
# 304     12/8/2015  INDICATED FOR THE TREATMENT OF PATIENTS WITH A...
#
#     CY 2020 CDER New Molecular Entity (NME) Drug & Original BLA Calendar Year Approvals\rAs of Decemeber 31, 2020\rThis report reflects the data shown as it is identified in the database.\rSelection Criteria:\rUser Response: Start Date: 1/1/2020    End Date: 12/31/2020\rSort Order: Approval Date  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 300                                                NaN
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
#
#     Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 300                NaN                NaN                NaN
# 301                NaN                NaN                NaN
# 302                NaN                NaN                NaN
# 303                NaN                NaN                NaN
# 304                NaN                NaN                NaN
#
#     Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 300                NaN                NaN                NaN
# 301                NaN                NaN                NaN
# 302                NaN                NaN                NaN
# 303                NaN                NaN                NaN
# 304                NaN                NaN                NaN
#
#     Unnamed: 7_level_0  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 300                NaN
# 301                NaN
# 302                NaN
# 303                NaN
# 304                NaN
#
#     CY 2018 CDER New Molecular Entity (NME) Drug & Original BLA Calendar Year Approvals\rAs of December 31, 2018\rThis report reflects the data shown as it is identified in the database.\rSelection Criteria:\rUser Response: Start Date: 1/1/2018    End Date: 12/31/2018\rSort Order: Approval Date
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 300                                                NaN
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
#
# [305 rows x 16 columns]

# %% [markdown]
# ### Get Compilation Data
#
# The FDA contains a site containing [Compilation Dataset links](https://www.fda.gov/drugs/drug-approvals-and-databases/compilation-cder-new-molecular-entity-nme-drug-and-new-biologic-approvals). This link points to a .csv file that can be downloaded and converted into a pd.DataFrame. This is already handled by FDAScrapper.
#
# If there are updates to the Compilation Dataset page, a different URL can be tested by passing in the url to the "url" parameter.
#
# As of this writing, the compilation dataset contains **NME and New Biologic Approvals from 1985-2023**

# %%
compilation = scrape.get_compilation()
compilation
# Out:
#      Proprietary  Name     Active Ingredient/Moiety  \
# 0               Lupron           leuprolide acetate
# 1              Seldane                  terfenadine
# 2              Ridaura                    auranofin
# 3              Marinol                   dronabinol
# 4               Fortaz                  ceftazidime
# ...                ...                          ...
# 1286          Ryzneuta  efbemalenograstim alfa-vuxw
# 1287           Ogsiveo                 nirogacestat
# 1288          Fabhalta                    iptacopan
# 1289          Filsuvez            birch triterpenes
# 1290            Wainua                  eplontersen
#
#                                     Applicant NDA/BLA   Application Number(1)  \
# 0                         TAP Pharmaceuticals     NDA                   19010
# 1                                 Merrell-Dow     NDA                   18949
# 2                         SmithKline & French     NDA                   18689
# 3                                      Unimed     NDA                   18651
# 4                                       Glaxo     NDA                   50578
# ...                                       ...     ...                     ...
# 1286  Evive Biotechnology Singapore PTE. Ltd.     BLA                  761134
# 1287           SpringWorks Therapeutics, Inc.     NDA                  217677
# 1288     Novartis Pharmaceuticals Corporation     NDA                  218276
# 1289                Amryt Pharmaceuticals DAC     NDA                  215064
# 1290              Ionis Pharmaceuticals, Inc.     NDA                  217388
#
#        Application Number(2)   Application Number(3) Dosage Form(1)  \
# 0                        NaN                     NaN     Injectable
# 1                        NaN                     NaN         Tablet
# 2                        NaN                     NaN        Capsule
# 3                        NaN                     NaN        Capsule
# 4                        NaN                     NaN     Injectable
# ...                      ...                     ...            ...
# 1286                     NaN                     NaN     Injectable
# 1287                     NaN                     NaN         Tablet
# 1288                     NaN                     NaN        Capsule
# 1289                     NaN                     NaN            Gel
# 1290                     NaN                     NaN     Injectable
#
#      Route of Administration(1) Dosage Form(2)  ...  \
# 0                     Injection            NaN  ...
# 1                          Oral            NaN  ...
# 2                          Oral            NaN  ...
# 3                          Oral            NaN  ...
# 4                     Injection            NaN  ...
# ...                         ...            ...  ...
# 1286                  Injection            NaN  ...
# 1287                       Oral            NaN  ...
# 1288                       Oral            NaN  ...
# 1289                    Topical            NaN  ...
# 1290                  Injection            NaN  ...
#
#                                         Approved Use(s)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1286  RYZNEUTA is indicated to decrease the incidenc...
# 1287  OGSIVEO is indicated for adult patients with p...
# 1288  FABHALTA is indicated for the treatment of adu...
# 1289  FILSUVEZ topical gel is indicated for the trea...
# 1290  WAINUA is indicated for the treatment of the p...
#
#                            Review Designation Orphan Drug Designation  \
# 0                                    Priority                      No
# 1                                    Priority                      No
# 2                                    Priority                      No
# 3                                    Priority                      No
# 4                                    Priority                      No
# ...                                       ...                     ...
# 1286                                 Standard                      No
# 1287                                 Priority                     Yes
# 1288  Priority (used priority review voucher)                     Yes
# 1289                                 Priority                     Yes
# 1290                                 Standard                     Yes
#
#      Accelerated Approval Breakthrough Therapy Designation  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
# ...                   ...                              ...
# 1286                   No                               No
# 1287                   No                              Yes
# 1288                   No                              Yes
# 1289                   No                               No
# 1290                   No                               No
#
#       Fast Track Designation Qualified Infectious Disease Product  \
# 0                        NaN                                  NaN
# 1                        NaN                                  NaN
# 2                        NaN                                  NaN
# 3                        NaN                                  NaN
# 4                        NaN                                  NaN
# ...                      ...                                  ...
# 1286                      No                                  NaN
# 1287                     Yes                                   No
# 1288                      No                                   No
# 1289                     Yes                                   No
# 1290                      No                                   No
#
#      Issued a Priority Review Voucher Redeemed a Priority Review Voucher Notes
# 0                                 NaN                                NaN   NaN
# 1                                 NaN                                NaN   NaN
# 2                                 NaN                                NaN   NaN
# 3                                 NaN                                NaN   NaN
# 4                                 NaN                                NaN   NaN
# ...                               ...                                ...   ...
# 1286                               No                                 No   NaN
# 1287                               No                                 No   NaN
# 1288                               No                                Yes   NaN
# 1289                              RPD                                 No   NaN
# 1290                               No                                 No   NaN
#
# [1291 rows x 27 columns]

# %% [markdown]
# # Get Current Approvals for Current Year
#
# Finally, the FDA curates [Novel Drug Approvals](https://www.fda.gov/drugs/development-approval-process-drugs/novel-drug-approvals-fda) for a given year. Information from this page can be used to obtain the current year drug approvals.
#
# A downside to this page is that it does not properly designate a drug as New Drug Application (NDA) or Biologics License Application (BLA). This would indicate small-molecule or biologics, respectively. A rule of thumb can be taken by the active ingredient names, where drugs ending in "mab" and "cept" can indicate biologics. However, confirmation should still be performed to ensure labeling accuracy.

# %%
latest = scrape.get_current_year()
latest
# Out:
#     Drug Name                  Active Ingredient Approval Date  \
# 0     Kisunla                     donanemab-azbt      7/2/2024
# 1   Ohtuvayre                       ensifentrine     6/26/2024
# 2      Piasky                    crovalimab-akkz     6/20/2024
# 3      Sofdra                        sofpironium     6/18/2024
# 4      Iqirvo                        elafibranor     6/10/2024
# 5      Rytelo                         imetelstat      6/6/2024
# 6   Imdelltra                    tarlatamab-dlle     5/16/2024
# 7    Xolremdi                        mavorixafor     4/26/2024
# 8      Ojemda                        tovorafenib     4/23/2024
# 9     Anktiva  nogapendekin alfa inbakicept-pmln     4/22/2024
# 10  Lumisight                      pegulicianine     4/17/2024
# 11    Zevtera      ceftobiprole medocaril sodium      4/3/2024
# 12    Voydeya                          danicopan     3/29/2024
# 13     Vafseo                         vadadustat     3/27/2024
# 14  Winrevair                   sotatercept-csrk     3/26/2024
# 15    Duvyzat                         givinostat     3/21/2024
# 16     Tryvio                       aprocitentan     3/19/2024
# 17  Rezdiffra                         resmetirom     3/14/2024
# 18   Tevimbra                  tislelizumab-jsgr     3/13/2024
# 19     Letybo           letibotulinumtoxinA-wlbg     2/29/2024
# 20   Exblifep           cefepime, enmetazobactam     2/22/2024
# 21   Zelsuvmi                         berdazimer      1/5/2024
#
#                    FDA-approved use on approval date*
# 0                        To treat Alzheimer’s disease
# 1      To treat chronic obstructive pulmonary disease
# 2        To treat paroxysmal nocturnal hemoglobinuria
# 3             To treat primary axillary hyperhidrosis
# 4   To treat primary biliary cholangitis in combin...
# 5   To treat low- to intermediate-1 risk myelodysp...
# 6     To treat extensive stage small cell lung cancer
# 7   To treat WHIM syndrome (warts, hypogammaglobul...
# 8   To treat relapsed or refractory pediatric low-...
# 9                             To treat bladder cancer
# 10  To use as an optical imaging agent for the det...
# 11  To treat certain bloodstream infections, bacte...
# 12  To treat extravascular hemolysis with paroxysm...
# 13      To treat anemia due to chronic kidney disease
# 14  To treat pulmonary arterial hypertension\nDrug...
# 15  To treat Duchenne muscular dystrophy in indivi...
# 16        To treat hypertension\nDrug Trials Snapshot
# 17  To treat noncirrhotic non-alcoholic steatohepa...
# 18  To treat unresectable or metastatic esophageal...
# 19  To temporarily improve the appearance of moder...
# 20  To treat complicated urinary tract infections\...
# 21  To treat molluscum contagiosum\nDrug Trials Sn...
