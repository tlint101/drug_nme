# %% [markdown]
# # Fetch Data From [openFDA](https://open.fda.gov)
#
# The following will display how to obtain approved drugs from multiple sources from [openFDA](https://open.fda.gov). For additional sources, please see the tutorial on obtaining approvals from Guide to Pharmacology, which can be found [here](PharmacologyDataFetcher.ipynb).

# %%
from drug_nme import FDADataFetcher

# %%
extract = FDADataFetcher()

# %%
df = extract.get_data()

# %%
df
# Out:
#        application_number     sponsor_name       active_ingredient  \
# 21              NDA017395          HOSPIRA  DOPAMINE HYDROCHLORIDE
# 161             NDA017463  MCNEIL CONSUMER               IBUPROFEN
# 1146            NDA017551     MALLINCKRODT   POTASSIUM PERCHLORATE
# 1151            NDA017556          RANBAXY             HALCINONIDE
# 1197            NDA017559         SCHERING               ALBUTEROL
# ...                   ...              ...                     ...
# 248685          NDA016194          HOSPIRA     PENTAZOCINE LACTATE
# 248971          NDA016624         ALLERGAN               MEDRYSONE
# 249018          NDA016636            ADAPT  NALOXONE HYDROCHLORIDE
# 250268          NDA016793  TEVA PARENTERAL              CYTARABINE
# 251436          NDA017015  ORGANON USA INC     PANCURONIUM BROMIDE
#
#           brand_name submission_type submission_number submission_status  \
# 21          INTROPIN            ORIG                 1                AP
# ...
