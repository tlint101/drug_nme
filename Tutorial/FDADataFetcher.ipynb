# %% [markdown]
# # Fetch Data From [openFDA](https://open.fda.gov)

# %%
from drug_nme.fetch import FDADataFetcher

# %%
extract = FDADataFetcher()

# %%
df = extract.get_data()
# Out:
# Downloading Data From OpenFDA: 7290KB [00:02, 2649.16KB/s]

# %%
df
# Out:
#        application_number          sponsor_name  \
# 286             NDA017454          MALLINCKRODT
# 334             NDA017473                  TEVA
# 513             NDA017559              SCHERING
# 530             NDA017594       WESTWOOD SQUIBB
# 970             NDA017628  ORTHO MCNEIL JANSSEN
# ...                   ...                   ...
# 251332          NDA014691            APOTEX INC
# 251454          NDA015197         CLOVER PHARMS
# 251603          NDA016224                BRACCO
# 251843          NDA016721    VALEANT PHARM INTL
# 251997          NDA016782                SOLVAY
#
#                        active_ingredient    brand_name submission_type  \
# 286     TECHNETIUM TC-99M ETIDRONATE KIT     OSTEOSCAN            ORIG
# 334                             PIMOZIDE          ORAP            ORIG
# 513                            ALBUTEROL     PROVENTIL            ORIG
# 530                           CHLOROXINE      CAPITROL            ORIG
# 970                      TOLMETIN SODIUM  TOLECTIN 600            ORIG
# ...                                  ...           ...             ...
# 251332                         MELPHALAN       ALKERAN            ORIG
# 251454                 AMINOCAPROIC ACID        AMICAR            ORIG
# 251603          ROSE BENGAL SODIUM I-131   ROBENGATOPE            ORIG
# 251843          FLURAZEPAM HYDROCHLORIDE       DALMANE            ORIG
# 251997                 LITHIUM CARBONATE     LITHONATE            ORIG
#
#        submission_number submission_status submission_status_date  \
# 286                    1                AP               19730928
# 334                    1                AP               19840731
# 513                    1                AP               19810501
# 530                    1                AP               19761019
# 970                    1                AP               19760324
# ...                  ...               ...                    ...
# 251332                 1                AP               19640117
# 251454                 1                AP               19640603
# 251603                 1                AP               19711123
# 251843                 1                AP               19700407
# 251997                 1                AP               19700406
#
#        review_priority submission_class_code submission_class_code_description
# 286           PRIORITY                TYPE 1     Type 1 - New Molecular Entity
# 334           STANDARD                TYPE 1     Type 1 - New Molecular Entity
# 513           PRIORITY                TYPE 1     Type 1 - New Molecular Entity
# 530           STANDARD                TYPE 1     Type 1 - New Molecular Entity
# 970           STANDARD                TYPE 1     Type 1 - New Molecular Entity
# ...                ...                   ...                               ...
# 251332        PRIORITY                TYPE 1     Type 1 - New Molecular Entity
# 251454        PRIORITY                TYPE 1     Type 1 - New Molecular Entity
# 251603        PRIORITY                TYPE 1     Type 1 - New Molecular Entity
# 251843        PRIORITY                TYPE 1     Type 1 - New Molecular Entity
# 251997        PRIORITY                TYPE 1     Type 1 - New Molecular Entity
#
# [1513 rows x 11 columns]
