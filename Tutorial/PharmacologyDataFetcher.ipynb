# %%
import pandas as pd
import re
from fda_nme.fetch import PharmacologyDataFetcher

# %%
extract = PharmacologyDataFetcher()

df = extract.get_data()
# Out:
# Downloading Data: 917KB [00:10, 88.09KB/s]

# %%
df
# Out:
#       ligandId                                 name               type  \
# 0         2779             1,25-dihydroxyvitamin D3         Metabolite
# 1         1013                   17&beta;-estradiol         Metabolite
# 2         4108  5&alpha;-pregnan-3&alpha;-ol-20-one         Metabolite
# 3         4784                5-aminolevulinic acid         Metabolite
# 4         4789                       5-fluorouracil  Synthetic organic
# ...        ...                                  ...                ...
# 1990      7430                            zopiclone  Synthetic organic
# 1991       103                             zotepine  Synthetic organic
# 1992     11576                          zucapsaicin  Synthetic organic
# 1993      7559                       zuclopenthixol  Synthetic organic
# 1994     12858                           zuranolone  Synthetic organic
#
#       approved  whoEssential  immuno  antibacterial  \
# 0         True         False   False          False
# 1         True         False   False          False
# 2         True         False   False          False
# 3         True         False   False          False
# 4         True          True   False          False
# ...        ...           ...     ...            ...
# 1990      True         False   False          False
# 1991      True         False   False          False
# 1992      True         False   False          False
# 1993      True         False   False          False
# 1994      True         False   False          False
#
#                              approvalSource
# 0                                FDA (1978)
# 1     FDA (1954, prior history unavailable)
# 2                                FDA (2019)
# 3                    FDA (1999)m EMA (2007)
# 4                                FDA (1962)
# ...                                     ...
# 1990
# 1991
# 1992                          Canada (2010)
# 1993
# 1994                             FDA (2023)
#
# [1995 rows x 8 columns]

# %%
working = df['approvalSource'].str.split(r'\(|\)', expand=True)

# %%
def process_string(text):
    # Split by parentheses
    parts = re.split(r'\(|\)', text)
    # Clean and strip parts
    parts = [part.strip(', ') for part in parts if part]

    result = {'FDA': None, 'FDA_year': None, 'UK': None, 'UK_year': None, 'EMA': None, 'EMA_year': None}

    # Process each part
    for i in range(0, len(parts), 2):
        if i + 1 < len(parts):  # Ensure there's a year part
            entities = parts[i]
            year = parts[i + 1]

            if 'FDA' in entities:
                result['FDA'] = entities
                result['FDA_year'] = year
            
            # comment this part out? 
            if 'UK' in entities:
                result['UK'] = entities
                result['UK_year'] = year
            if 'EMA' in entities:
                result['EMA'] = entities
                result['EMA_year'] = year

    return pd.Series(result)

# %%
# Apply the function to the dataframe
working = df['approvalSource'].apply(process_string)

working
# Out:
#        FDA                         FDA_year    UK UK_year   EMA EMA_year
# 0      FDA                             1978  None    None  None     None
# 1      FDA  1954, prior history unavailable  None    None  None     None
# 2      FDA                             2019  None    None  None     None
# 3      FDA                             1999  None    None  None     None
# 4      FDA                             1962  None    None  None     None
# ...    ...                              ...   ...     ...   ...      ...
# 1990  None                             None  None    None  None     None
# 1991  None                             None  None    None  None     None
# 1992  None                             None  None    None  None     None
# 1993  None                             None  None    None  None     None
# 1994   FDA                             2023  None    None  None     None
#
# [1995 rows x 6 columns]
