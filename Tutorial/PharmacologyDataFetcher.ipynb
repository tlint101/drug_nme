# %% [markdown]
# # Fetch Data From [Guide to Pharmacology](https://www.guidetopharmacology.org)
#
# The following will display how to obtain approved drugs from multiple sources from Guide to Pharmacology. By default, the program will output for FDA. However, the scripts can be configured to identify drugs that are approved from other countries. This will be demoed below.

# %%
from drug_nme.fetch import PharmacologyDataFetcher

# %%
extract = PharmacologyDataFetcher()

df = extract.get_data(agency='fda')

# %%
df
# Out:
#       ligandId                                 name               type  \
# 0         2779             1,25-dihydroxyvitamin D3         Metabolite
# 1         1013                   17&beta;-estradiol         Metabolite
# 2         4108  5&alpha;-pregnan-3&alpha;-ol-20-one         Metabolite
# 3         4784                5-aminolevulinic acid         Metabolite
# 4         4789                       5-fluorouracil  Synthetic organic
# ...        ...                                  ...                ...
# 1986      3177                      zoledronic acid  Synthetic organic
# 1987        60                         zolmitriptan  Synthetic organic
# 1988      4348                             zolpidem  Synthetic organic
# 1989      7047                           zonisamide  Synthetic organic
# 1994     12858                           zuranolone  Synthetic organic
#
#       approved  withdrawn  whoEssential  \
# 0         True      False         False
# ...
