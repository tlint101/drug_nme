# %% [markdown]
# # Fetch Data From [Guide to Pharmacology](https://www.guidetopharmacology.org)

# %%
import pandas as pd
import re
from drug_nme.fetch import PharmacologyDataFetcher

# %%
extract = PharmacologyDataFetcher()

df = extract.get_data()
# Out:
# Downloading Data From Guide To Pharmacology: 912KB [00:09, 95.94KB/s]

# %%
df
# Out:
#       ligandId                                 name abbreviation  \
# 0         2779             1,25-dihydroxyvitamin D3
# 1         1013                   17&beta;-estradiol           E2
# 2         4108  5&alpha;-pregnan-3&alpha;-ol-20-one
# 3         4784                5-aminolevulinic acid
# 4         4789                       5-fluorouracil
# ...        ...                                  ...          ...
# 1990      7430                            zopiclone
# 1991       103                             zotepine
# 1992     11576                          zucapsaicin
# 1993      7559                       zuclopenthixol
# 1994     12858                           zuranolone
#
#                  inn               type species  radioactive  labelled  \
# 0         calcitriol         Metabolite    None        False     False
# 1          estradiol         Metabolite    None        False     False
# 2        brexanolone         Metabolite    None        False     False
# 3                            Metabolite    None        False     False
# 4       fluorouracil  Synthetic organic    None        False     False
# ...              ...                ...     ...          ...       ...
# 1990       zopiclone  Synthetic organic    None        False     False
# 1991        zotepine  Synthetic organic    None        False     False
# 1992     zucapsaicin  Synthetic organic    None        False     False
# 1993  zuclopenthixol  Synthetic organic    None        False     False
# 1994      zuranolone  Synthetic organic    None        False     False
#
#       approved  withdrawn  whoEssential  immuno  malaria  antibacterial  \
# 0         True      False         False   False    False          False
# 1         True      False         False   False    False          False
# 2         True      False         False   False    False          False
# 3         True      False         False   False    False          False
# 4         True      False          True   False    False          False
# ...        ...        ...           ...     ...      ...            ...
# 1990      True      False         False   False    False          False
# 1991      True      False         False   False    False          False
# 1992      True      False         False   False    False          False
# 1993      True      False         False   False    False          False
# 1994      True      False         False   False    False          False
#
#                              approvalSource subunitIds complexIds  \
# 0                                FDA (1978)         []         []
# 1     FDA (1954, prior history unavailable)         []         []
# 2                                FDA (2019)         []         []
# 3                    FDA (1999)m EMA (2007)         []         []
# 4                                FDA (1962)         []         []
# ...                                     ...        ...        ...
# 1990                                                []         []
# 1991                                                []         []
# 1992                          Canada (2010)         []         []
# 1993                                                []         []
# 1994                             FDA (2023)         []         []
#
#         prodrugIds activeDrugIds
# 0               []            []
# 1           [7655]            []
# 2               []            []
# 3               []            []
# 4     [6799, 4801]            []
# ...            ...           ...
# 1990            []            []
# 1991            []            []
# 1992            []            []
# 1993            []            []
# 1994            []            []
#
# [1995 rows x 19 columns]

# %%
working = df['approvalSource'].str.split(r'\(|\)', expand=True)

# %%
def process_string(text):
    # Split by parentheses
    parts = re.split(r'\(|\)', text)
    # Clean and strip parts
    parts = [part.strip(', ') for part in parts if part]

    result = {'FDA': None, 'FDA_year': None, 'UK': None, 'UK_year': None, 'EMA': None, 'EMA_year': None}

    # Process each part
    for i in range(0, len(parts), 2):
        if i + 1 < len(parts):  # Ensure there's a year part
            entities = parts[i]
            year = parts[i + 1]

            if 'FDA' in entities:
                result['FDA'] = entities
                result['FDA_year'] = year
            
            # comment this part out? 
            if 'EMA' in entities:
                result['EMA'] = entities
                result['EMA_year'] = year
            if 'UK' in entities:
                result['UK'] = entities
                result['UK_year'] = year
            if 'Japan' in entities:
                result['Japan'] = entities
                result['Japan_year'] = year
            if 'China' in entities:
                result['China'] = entities
                result['China_year'] = year

    return pd.Series(result)

# %%
# Apply the function to the dataframe
working = df['approvalSource'].apply(process_string)

working

# %%
new = pd.concat([df, working], axis=1)
new

# %%
from drug_nme.fetch import FDADataFetcher

extract = FDADataFetcher()

# %%
df = extract.get_data()
df

# %%
import requests
from tqdm import tqdm
import zipfile
import io
import json

# URL of the zip file
url = "https://download.open.fda.gov/drug/drugsfda/drug-drugsfda-0001-of-0001.json.zip"

# Stream the download and show progress bar
response = requests.get(url, stream=True)
response.raise_for_status()  # Check if the request was successful

total_size = int(response.headers.get('content-length', 0))
block_size = 1024  # 1 Kibibyte
progress_bar = tqdm(total=total_size, unit='iB', unit_scale=True)

file_bytes = io.BytesIO()
for data in response.iter_content(block_size):
    progress_bar.update(len(data))
    file_bytes.write(data)
progress_bar.close()

# Move to the start of the BytesIO buffer
file_bytes.seek(0)

# Create a ZipFile object from the downloaded content
with zipfile.ZipFile(file_bytes) as z:
    # Extract the JSON file
    json_filename = z.namelist()[0]  # Assuming there's only one file in the zip
    with z.open(json_filename) as json_file:
        data = json.load(json_file)

# Now 'data' contains the contents of the JSON file

# %%
import requests
from tqdm import tqdm
import zipfile
import io
import json
import pandas as pd

# URL of the zip file
url = "https://download.open.fda.gov/drug/drugsfda/drug-drugsfda-0001-of-0001.json.zip"

# Stream the download and show progress bar
response = requests.get(url, stream=True)
response.raise_for_status()  # Check if the request was successful

total_size = int(response.headers.get('content-length', 0))
block_size = 1024  # 1 Kibibyte
progress_bar = tqdm(total=total_size, unit='iB', unit_scale=True)

file_bytes = io.BytesIO()
for data in response.iter_content(block_size):
    progress_bar.update(len(data))
    file_bytes.write(data)
progress_bar.close()

# Move to the start of the BytesIO buffer
file_bytes.seek(0)

# Create a ZipFile object from the downloaded content
with zipfile.ZipFile(file_bytes) as z:
    # Extract the JSON file
    json_filename = z.namelist()[0]  # Assuming there's only one file in the zip
    with z.open(json_filename) as json_file:
        data = json.load(json_file)

# %%
data

# %%
# df = pd.json_normalize(data)
df = pd.DataFrame(data['results'])
df
